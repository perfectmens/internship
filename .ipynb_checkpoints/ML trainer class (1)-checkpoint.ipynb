# %% [markdown]
# Mechine Learning
#
#  Machine Learning is a subset of artificial intelligence (Ai).
# It makes the machine learn from past data and make predictions.
# It involves training algorithms to learn patterns from data and make predictions or decisions.
#
# Work flow for mechine learning :-
#
# 1-data collection(gather data from various sources).
#
# 2-data preprocessing(clean and prepare data analysis).
#
# 3-data analysis,data visualization.(Exploring the data to understand its structure, patterns, and relationships.)
#
# 4-feature engneering.(Creating new features or modifying existing ones to improve the model's performance.)
#
# 5-model training.(Using the prepared data to train a machine learning model.)
#
# 6-model evaluation.(Assessing the model's performance using metrics like accuracy, precision, recall, F1 score, and mean squared error.)
#
# 7-model deployment.(Integrating the trained model into a production environment where it can make real-time predictions or decisions based on new data.)

# %% [markdown]
# ##### Mechine learning has two types supervised and un supervised learning
# Supervised:- Regression and Classification
#
# Unsupervised:- clustering

# %% [markdown]
# ###### Supervised and Unsupervised
# "Supervised machine learning is trained using well-labeled training data. This means some input data is already tagged with the correct output. Finding the relationship between the input variable and the output variable is called regression. The input variable is known as the independent variable or feature (which can be any value), while the output is known as the dependent variable or target (there is always one dependent variable and one output)."
#
# "Unsupervised machine learning involves training machines using unlabeled training data. Based on this data, the machine identifies patterns and structures without predicting specific outcomes. Clustering is a method used in unsupervised learning to group similar data points into clusters. The goal is to have data points within the same cluster that are more similar to each other than to those in other clusters."

# %% [markdown]
# ###### Regression: Regression algorithms are used to predict continuous outcomes based on input data.
# 1)Linear Regression: When there is a linear relationship between the dependent and independent variables.
#
# Applications: Predicting house prices, sales forecasting, and risk assessment.

# %% [markdown]
# ###### Classification:  classification algorithms are used to predict categorical outcomes based on input data.
# 1)Logistic Regression:Models the probability of a binary outcome (0 or 1) based on one or more predictor variables.
#
# Applications: Spam detection, disease diagnosis.
#
# 2)k-Nearest Neighbors (k-NN):Classifies a data point based on the majority class among its k nearest neighbors.
#
# Applications: Recommender systems, anomaly detection.
#
# 3)Decision Trees:Splits the data into branches to form a tree based on feature values, making decisions at each node.
#
# Applications: Customer segmentation, credit risk analysis.
#
# 4)Random Forest:An ensemble method that combines multiple decision trees to improve accuracy and reduce overfitting.
#
# Feature selection, fraud detection.
#
# 5)Support Vector Machines (SVM):Finds the optimal hyperplane that separates classes in a high-dimensional space.
#
# Applications: Image classification, text categorization.
#
# 6)Naive Bayes:Based on Bayes' theorem, assuming independence between features.
#
# Applications: Text classification, spam filtering.

# %% [markdown]
# ###### Clustering
# "K-means clustering is a method used to group similar data points together into clusters. The goal is to have data points in the same cluster that are more similar to each other than to those in other clusters. Here, we do not predict outcomes but rather find patterns. We do not use train-test splits; only independent variables are given."

# %% [markdown]
# ###### Linear Regression

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
df=pd.read_csv("Salary_dataset.csv")
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
#df.isna().sum()
df.isna().any()
# Out:
# Unnamed: 0         False
# YearsExperience    False
# Salary             False
# dtype: bool

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df
df.info()
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
#x=df.iloc[:,0]
#x
x=df[["YearsExperience"]]
x
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
#y=df.iloc[:,1]
#y
y=df["Salary"]
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train,x_test,y_train,y_test)
# Out:
#     YearsExperience
# 0               1.2
# 4               2.3
# 16              5.2
# 5               3.0
# 13              4.2
# 11              4.1
# 22              8.0
# 1               1.4
# 2               1.6
# 25              9.1
# 3               2.1
# 21              7.2
# 26              9.6
# 18              6.0
# 29             10.6
# 20              6.9
# 7               3.3
# 10              4.0
# 14              4.6
# 19              6.1
# 6               3.1     YearsExperience
# 27              9.7
# 15              5.0
# 23              8.3
# 17              5.4
# 8               3.3
# 9               3.8
# 28             10.4
# 24              8.8
# 12              4.1 0      39344.0
# 4      39892.0
# 16     66030.0
# 5      56643.0
# 13     57082.0
# 11     55795.0
# 22    101303.0
# 1      46206.0
# 2      37732.0
# 25    105583.0
# 3      43526.0
# 21     98274.0
# 26    116970.0
# 18     81364.0
# 29    121873.0
# 20     91739.0
# 7      54446.0
# 10     63219.0
# 14     61112.0
# 19     93941.0
# 6      60151.0
# Name: Salary, dtype: float64 27    112636.0
# 15     67939.0
# 23    113813.0
# 17     83089.0
# 8      64446.0
# 9      57190.0
# 28    122392.0
# 24    109432.0
# 12     56958.0
# Name: Salary, dtype: float64

# %%
#model training
model=LinearRegression()
model.fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %%
#tested data
y_pred=model.predict(x_test)
y_pred
# Out:
# array([115574.62288352,  71680.93878159, 102499.90847018,  75416.57147111,
#         55804.4998511 ,  60474.04071301, 122111.98009019, 107169.44933209,
#         63275.76523015])

# %%
#compare the actual data with predictedvalues
y_test
# Out:
# 27    112636.0
# 15     67939.0
# 23    113813.0
# 17     83089.0
# 8      64446.0
# 9      57190.0
# 28    122392.0
# 24    109432.0
# 12     56958.0
# Name: Salary, dtype: float64

# %%
#model performance or evaluation
mse=mean_squared_error(y_test,y_pred)#average difference b\w actua and predicted values
print(mse)
# Out:
# 37784662.46621308

# %%
#mae--mean absolute error(average b\w absolute difference of predicted and actual data)
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 5161.328710400181

# %%
#r2score is the proportion of the varience in the dependent variable that is predictable
r2score=r2_score(y_test,y_pred)
print(r2score)
# Out:
# 0.9414466227178215

# %%
#predict the new data

new_experience=np.array([[5]])#predicting salary for 5 years of experience
predicted_salary=model.predict(new_experience)
print(f"predicting salary for 5 years of experience:${predicted_salary[0]:.2f}")
# Out:
# predicting salary for 5 years of experience:$71680.94
# C:\Users\91944\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#plot the results
plt.scatter(x,y,color="blue",label="actual data")
plt.plot(x,model.predict(x),color="red",linewidth=2,label="Regression line")
plt.xlabel("YearsExperience")
plt.ylabel("salary")
plt.title("yearsof experience vs salary")
plt.legend()
plt.show()

# %% [markdown]
# ###### Logistic Regression
# a classification algorithm used for binary classification problems,where the outcomes or dependent variable can take one of two possible values(eg-yes\no,true\false).it is used to model the probability that a given input belongs to a certain class
#
# application: we can use in medical field email spam disiese detection etc.. it is a descrete

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report,precision_score
from sklearn.preprocessing import StandardScaler

# %%
dt=pd.read_csv("pq.csv")
dt
# Out:
#       male  age  currentSmoker  cigsPerDay    BPMeds  prevalentStroke  \
# 0        1   39              0         0.0  0.000000                0
# 1        0   46              0         0.0  0.000000                0
# 2        1   48              1        20.0  0.000000                0
# 3        0   61              1        30.0  0.000000                0
# 4        0   46              1        23.0  0.000000                0
# ...    ...  ...            ...         ...       ...              ...
# 4235     0   48              1        20.0  0.029615                0
# 4236     0   44              1        15.0  0.000000                0
# 4237     0   52              0         0.0  0.000000                0
# 4238     1   40              0         0.0  0.000000                0
# 4239     0   39              1        30.0  0.000000                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4235             0         0    248.0  131.0   72.0  22.00       84.0
# 4236             0         0    210.0  126.5   87.0  19.16       86.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
# 4238             1         0    185.0  141.0   98.0  25.60       67.0
# 4239             0         0    196.0  133.0   86.0  20.91       85.0
#
#          glucose  TenYearCHD
# 0      77.000000           0
# 1      76.000000           0
# 2      70.000000           0
# 3     103.000000           1
# 4      85.000000           0
# ...          ...         ...
# 4235   86.000000           0
# 4236   81.963655           0
# 4237  107.000000           0
# 4238   72.000000           0
# 4239   80.000000           0
#
# [4240 rows x 15 columns]

# %%
dt.isna().sum()
# Out:
# male               0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
dt.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dt.dropna(inplace=True)
#       2 dt.to_string
#
# NameError: name 'dt' is not defined

# %%
x=dt.iloc[:,:-1]
x
# Out:
#       male  age  currentSmoker  cigsPerDay    BPMeds  prevalentStroke  \
# 0        1   39              0         0.0  0.000000                0
# 1        0   46              0         0.0  0.000000                0
# 2        1   48              1        20.0  0.000000                0
# 3        0   61              1        30.0  0.000000                0
# 4        0   46              1        23.0  0.000000                0
# ...    ...  ...            ...         ...       ...              ...
# 4235     0   48              1        20.0  0.029615                0
# 4236     0   44              1        15.0  0.000000                0
# 4237     0   52              0         0.0  0.000000                0
# 4238     1   40              0         0.0  0.000000                0
# 4239     0   39              1        30.0  0.000000                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4235             0         0    248.0  131.0   72.0  22.00       84.0
# 4236             0         0    210.0  126.5   87.0  19.16       86.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
# 4238             1         0    185.0  141.0   98.0  25.60       67.0
# 4239             0         0    196.0  133.0   86.0  20.91       85.0
#
#          glucose
# 0      77.000000
# 1      76.000000
# 2      70.000000
# 3     103.000000
# 4      85.000000
# ...          ...
# 4235   86.000000
# 4236   81.963655
# 4237  107.000000
# 4238   72.000000
# 4239   80.000000
#
# [4240 rows x 14 columns]

# %%
y=dt["TenYearCHD"]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4235    0
# 4236    0
# 4237    0
# 4238    0
# 4239    0
# Name: TenYearCHD, Length: 4240, dtype: int64

# %%
ss= StandardScaler()
X_scaled = ss.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train,x_test,y_train,y_test)
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 4097     1   54              1        40.0     0.0                0
# 3165     1   44              1        30.0     0.0                0
# 2499     0   46              1        15.0     0.0                0
# 3345     1   38              1        15.0     0.0                0
# 3596     1   40              1        15.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 3444     0   36              1         5.0     0.0                0
# 466      0   57              1        15.0     0.0                0
# 3092     0   60              0         0.0     0.0                0
# 3772     1   39              1        10.0     0.0                0
# 860      0   35              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# 4097             0         0    245.0  152.0   82.0  23.71       75.0     75.0
# 3165             0         0    363.0  140.0   87.0  26.44       95.0     79.0
# 2499             0         0    232.0  115.0   70.0  25.18       75.0     59.0
# 3345             0         0    150.0  123.0   76.0  20.39       60.0     82.0
# 3596             0         0    200.0  122.5   75.0  20.25       60.0     67.0
# ...            ...       ...      ...    ...    ...    ...        ...      ...
# 3444             1         0    222.0  147.0   94.0  26.79       76.0     71.0
# 466              0         0    250.0  125.0   74.0  21.08       80.0     72.0
# 3092             1         0    298.0  133.0   89.0  25.09       83.0     81.0
# 3772             0         0    215.0  102.0   64.5  24.50       68.0     62.0
# 860              0         0    248.0  107.0   73.0  20.64       90.0     80.0
#
# [2968 rows x 14 columns]       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 1350     0   49              1        10.0     0.0                0
# 1434     1   43              1        25.0     0.0                0
# 2500     1   45              1         1.0     0.0                0
# 1128     0   63              1        10.0     0.0                0
# 4144     1   59              0         0.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 1859     0   67              1         3.0     0.0                0
# 3164     1   39              1        30.0     0.0                0
# 610      1   55              1        15.0     0.0                0
# 570      0   49              1         3.0     0.0                0
# 343      1   43              1        25.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 1350             0         0    260.0  123.0   80.0  23.10       63.0
# 1434             0         0    201.0  121.0   82.0  23.84       70.0
# 2500             1         0    277.0  140.0   84.0  28.74       69.0
# 1128             1         0    236.0  189.0  103.0  27.91       60.0
# 4144             0         0    237.0  131.5   84.0  24.17       90.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 1859             1         0    326.0  157.5   78.0  24.63       85.0
# 3164             1         0    292.0  153.0  100.0  28.09      110.0
# 610              1         0    222.0  155.0   92.5  28.35       67.0
# 570              0         0    247.0  121.0   82.0  29.07       72.0
# 343              0         0    245.0  126.0   88.5  23.16       92.0
#
#         glucose
# 1350  65.000000
# 1434  91.000000
# 2500  74.000000
# 1128  74.000000
# 4144  94.000000
# ...         ...
# 1859  77.000000
# 3164  69.000000
# 610   68.000000
# 570   69.000000
# 343   81.963655
#
# [1272 rows x 14 columns] 4097    0
# 3165    0
# 2499    1
# 3345    0
# 3596    0
#        ..
# 3444    0
# 466     0
# 3092    0
# 3772    0
# 860     0
# Name: TenYearCHD, Length: 2968, dtype: int64 1350    1
# 1434    0
# 2500    0
# 1128    0
# 4144    1
#        ..
# 1859    0
# 3164    1
# 610     1
# 570     0
# 343     1
# Name: TenYearCHD, Length: 1272, dtype: int64

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
model
# Out:
# C:\Users\91944\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
acc_score = accuracy_score(y_test, y_pred)
print(acc_score)
# Out:
# 0.85062893081761

# %%
cnf=confusion_matrix(y_test,y_pred) #it is matrix table which displays the number of correctly predited values and incorrectly predicted values
print(cnf)                         #[[tp(true postve)(correcly)    fp(false postve
                                   # fn(incoreclty)                   tn(correcly)]]
# Out:
# [[1072    5]
#  [ 185   10]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      1077
#            1       0.67      0.05      0.10       195
#
#     accuracy                           0.85      1272
#    macro avg       0.76      0.52      0.51      1272
# weighted avg       0.82      0.85      0.79      1272

# %%
prec=precision_score(y_test,y_pred)
prec
# Out:
# 0.6666666666666666

# %%
new_data= np.array([[50, 1, 1, 0, 110, 70, 240, 0, 0, 0, 40, 30.0, 0.5, 80,]])
new= ss.transform(new_data)
predicted_prob = model.predict_proba(new)
print(f'Predicted probability of 10-year CHD: {predicted_prob[0][1]:.2f}')
# Out:
# Predicted probability of 10-year CHD: 1.00
# C:\Users\91944\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\91944\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ###### Clustering
# K-MEANs CLUSTERING
# is a method used to group similar data points together into cluster.the goal is to have thedata points in the same cluster that are more similar to each other than to those in other cluster --here we do not predict only to find the pattern.we donot use train test here only independent variable is given

# %%
import numpy as np    
import matplotlib.pyplot as plt    
import pandas as pd    
import seaborn as sns
from sklearn.cluster import KMeans

# %%
data={
    'students':('a','b','c','d','e','f','g','h'),
    'maths score':(89,67,78,45,62,98,78,98),
    'science score':(89,78,90,78,67,89,98,78),
}

# %%
data
# Out:
# {'students': ('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'),
#  'maths score': (89, 67, 78, 45, 62, 98, 78, 98),
#  'science score': (89, 78, 90, 78, 67, 89, 98, 78)}

# %%
df=pd.DataFrame(data)
df
# Out:
#   students  maths score  science score
# 0        a           89             89
# 1        b           67             78
# 2        c           78             90
# 3        d           45             78
# 4        e           62             67
# 5        f           98             89
# 6        g           78             98
# 7        h           98             78

# %%
x=df[["maths score","science score"]]
x
# Out:
#    maths score  science score
# 0           89             89
# 1           67             78
# 2           78             90
# 3           45             78
# 4           62             67
# 5           98             89
# 6           78             98
# 7           98             78

# %%
x=df[["maths score","science score"]]
x
# Out:
#    maths score  science score
# 0           89             89
# 1           67             78
# 2           78             90
# 3           45             78
# 4           62             67
# 5           98             89
# 6           78             98
# 7           98             78

# %%
k=3

# %%
kmeans=KMeans(n_clusters=k,random_state=0)
kmeans.fit(x)
# Out:
# C:\Users\91944\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\91944\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3, random_state=0)

# %%
labels=kmeans.labels_
df['cluster']=labels
df['cluster']
# Out:
# 0    1
# 1    0
# 2    2
# 3    0
# 4    0
# 5    1
# 6    2
# 7    1
# Name: cluster, dtype: int32

# %%
df
# Out:
#   students  maths score  science score  cluster
# 0        a           89             89        1
# 1        b           67             78        0
# 2        c           78             90        2
# 3        d           45             78        0
# 4        e           62             67        0
# 5        f           98             89        1
# 6        g           78             98        2
# 7        h           98             78        1

# %%
plt.figure(figsize=(10,6))
colors =plt.get_cmap('viridis',k)
for cluster in range(k):
    cluster_data=df[df['cluster']==cluster]
    plt.scatter(cluster_data['maths score'],cluster_data['science score'],color=colors(cluster),label=f'cluster{cluster+1}')
centroids=kmeans.cluster_centers_
plt.scatter(centroids[:,0],centroids[:,1],color='black',marker='x',s=100,label='centroids')#s is size centroid
plt.xlabel('maths score')
plt.ylabel('science score')
plt.title('maths score')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Sample Data (replace this with actual social media data)
data = {
    'tweet': [
        "I love the new design!",
        "This is the worst update ever.",
        "Amazing features in this app.",
        "Not happy with the service.",
        "I’m so excited to use this!",
        "Terrible experience, disappointed.",
        "Best app ever! So useful.",
        "Very bad UI, not user-friendly."
    ],
    'sentiment': [
        "positive", "negative", "positive", "negative",
        "positive", "negative", "positive", "negative"
    ]
}

# Load data into a DataFrame
df = pd.DataFrame(data)

# Convert sentiment to binary (positive = 1, negative = 0)
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(df['tweet'], df['sentiment'], test_size=0.25, random_state=42)

# Vectorize text data
vectorizer = CountVectorizer()
X_train_vectors = vectorizer.fit_transform(X_train)
X_test_vectors = vectorizer.transform(X_test)

# Train a Logistic Regression model
model = LogisticRegression()
model.fit(X_train_vectors, y_train)

# Predict and evaluate
y_pred = model.predict(X_test_vectors)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Test on new tweet
test_tweet = ["I hate the new update!"]
test_vector = vectorizer.transform(test_tweet)
prediction = model.predict(test_vector)
print("\nSentiment Prediction:", "Positive" if prediction[0] == 1 else "Negative")
# Out:
# Accuracy: 0.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       2.0
#            1       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
#
#
# Sentiment Prediction: Positive
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# Sample DataFrame
data = pd.DataFrame({
    'age': [21, 35, 45, 18],
    'comment': ['I love it', 'Terrible service', 'Great experience', 'Not good'],
    'label': [1, 0, 1, 0]
})

# Feature & Label split
X = data[['age', 'comment']]
y = data['label']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Preprocessing: text + numeric
preprocessor = ColumnTransformer(
    transformers=[
        ('text', TfidfVectorizer(), 'comment'),     # Text column
        ('num', StandardScaler(), ['age'])          # Numeric column
    ]
)

# Create Pipeline
clf = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression())
])

# Train model
clf.fit(X_train, y_train)

# Predict
predictions = clf.predict(X_test)
print(predictions)
